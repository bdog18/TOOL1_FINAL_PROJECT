# %%
import pandas as pd

# %% [markdown]
# Data Loading

# %%
terror_df = pd.read_csv("GlobalTerrorism/GlobalTerrorismDataset.csv", encoding="latin-1")

life_df = pd.read_csv("LifeExpectancy/LifeExpectancyAtBirth.csv", encoding="latin-1")
# Out:
# C:\Users\Brend\AppData\Local\Temp\ipykernel_9240\1304365707.py:1: DtypeWarning: Columns (4,31,33,54,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   terror_df = pd.read_csv("GlobalTerrorism/GlobalTerrorismDataset.csv", encoding="latin-1")

# %% [markdown]
# Data Cleaning

# %%
# Get min and max years for both dfs
life_yr_min = life_df["Year"].min()
life_yr_max = life_df["Year"].max()
terror_yr_min = terror_df["iyear"].min()
terror_yr_max = terror_df["iyear"].max()

# Filter dfs so that they are both using the same year ranges
terror_df = terror_df[(terror_df["iyear"] >= life_yr_min) & (terror_df["iyear"] <= life_yr_max)]
life_df = life_df[(life_df["Year"] >= terror_yr_min) & (life_df["Year"] <= terror_yr_max)]

# %%
# num_na = terror_df.isna().sum()
# for col in num_na.index: 
#     # if num_na[col] > 0: 
#     print(col, num_na[col])

# Not a finished list of columns of interest
cols_of_interest = [
    "iyear",
    "imonth",
    "iday",
    "country_txt",
    "region_txt",
    "multiple",
    "success",
    "suicide",
    "attacktype1",
    "attacktype1_txt",
    "targtype1",
    "targtype1_txt",
    "weaptype1",
    "weaptype1_txt"
]
terror_df = terror_df.loc[:, cols_of_interest]
terror_df
# Out:
#         iyear  imonth  iday         country_txt                   region_txt  \
# 0        1970       7     2  Dominican Republic  Central America & Caribbean
# 1        1970       0     0              Mexico                North America
# 2        1970       1     0         Philippines               Southeast Asia
# 3        1970       1     0              Greece               Western Europe
# 4        1970       1     0               Japan                    East Asia
# ...       ...     ...   ...                 ...                          ...
# 157458   2015      12    31             Somalia           Sub-Saharan Africa
# 157459   2015      12    31               Libya   Middle East & North Africa
# 157460   2015      12    31        South Africa           Sub-Saharan Africa
# 157554   2015      12    31               India                   South Asia
# 157907   2015      12    17               Libya   Middle East & North Africa
#
# ...
